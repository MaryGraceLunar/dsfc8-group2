# %% [markdown]
# # DATA WRANGLING

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

pd.set_option('display.float_format', '{:,.4f}'.format)
pd.set_option('max_columns', 100)

# %%
df_raw = pd.read_csv('data/2019-candidate-campaigns.csv', index_col=0)
df_raw.fillna(0, inplace=True)
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62 entries, 1 to 61
# Data columns (total 41 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Candidate                                            62 non-null     object
#  1   Coalition                                            62 non-null     object
#  2   Party                                                62 non-null     object
#  3   Twitter - Number of Mentions                         62 non-null     float64
#  4   Twitter - Number of Users                            62 non-null     float64
#  5   Twitter- Total Favorites                             62 non-null     float64
#  6   Twitter - Total Retweets                             62 non-null     float64
#  7   Twitter - Total Replies                              62 non-null     float64
#  8   Twitter - Percent News                               62 non-null     float64
#  9   Twitter - Percent Non-news                           62 non-null     float64
#  10  Facebook - Number of Candidate Posts                 62 non-null     float64
#  11  Facebook - Total Comments                            62 non-null     float64
#  12  Facebook - Total Shares                              62 non-null     float64
#  13  Facebook - Total Reactions                           62 non-null     float64
#  14  Political Party                                      62 non-null     object
#  15  Win                                                  62 non-null     float64
#  16  Cash Contributions Received from Other Sources       62 non-null     float64
#  17  In-Kind Contributions Received from Other Sources    62 non-null     float64
#  18  Cash Contributions Received from Political Party     62 non-null     float64
#  19  In-Kind Contributions Received from Political Party  62 non-null     float64
#  20  Total Contributions Received                         62 non-null     float64
#  21  Expenditures Paid Out of Personal Funds              62 non-null     float64
#  22  Expenditures Paid Out of Cash Contributions          62 non-null     float64
#  23  Expenditures Incurred Using In-Kind Contribution     62 non-null     float64
#  24  Total Expenditures Incurred                          62 non-null     float64
#  25  Difference (Contribution less Expenditure)           62 non-null     float64
#  26  Unpaid Obligation / Balance                          62 non-null     float64
#  27  Travel Expenses                                      62 non-null     float64
#  28  Compensation of campaigners, etc.                    62 non-null     float64
#  29  Communications                                       62 non-null     float64
#  30  Stationery, Printing, and Distribution               62 non-null     float64
#  31  Employment of Poll Watchers                          62 non-null     float64
#  32  Rent, Maintenance, etc.                              62 non-null     float64
#  33  Political Meetings and Rallies                       62 non-null     float64
#  34  Pol Ads                                              62 non-null     float64
#  35  Total SLE                                            62 non-null     float64
#  36  Employment of Counsel                                62 non-null     float64
#  37  Copying and Classifying List of Voters               62 non-null     float64
#  38  Printing of Sample Ballots                           62 non-null     float64
#  39  Total Expenditures                                   62 non-null     float64
#  40  Difference Total in SCE minus Total SLE              62 non-null     float64
# dtypes: float64(37), object(4)
# memory usage: 20.3+ KB

# %%
candidates = df_raw.iloc[:, 0:3]
contrib = df_raw.loc[:, 'Win': 'Total Contributions Received'].fillna(0)
df = pd.concat([candidates,contrib], axis =1)

# %%
candidates = df_raw.iloc[:, 0:3]
contrib = df_raw.loc[:, 'Win': 'Total Contributions Received'].fillna(0)
df = pd.concat([candidates,contrib], axis =1)
df['Total Cash Contributions'] = df['Cash Contributions Received from Other Sources'] + df['Cash Contributions Received from Political Party']
df['Total In-Kind Contributions'] = df['In-Kind Contributions Received from Other Sources'] + df['In-Kind Contributions Received from Political Party']
df
# Out:
#                           Candidate       Coalition        Party    Win  \
# Candidate Number
# 1                      Abner Afuang             WPP          WPP 0.0000
# 2                    Agnes Escudero             KKK  Independent 0.0000
# 3                     Allan Montaño       Labor Win  Independent 0.0000
# 4                 Balde Baldevarona               0  Independent 0.0000
# 5                        Bam Aquino    Otso Diretso      Liberal 0.0000
# ...                             ...             ...          ...    ...
# 57                   Shariff Albani             WPP          WPP 0.0000
# 58                     Sonny Angara             HNP          LDP 1.0000
# 59                     Sonny Matula  Labor Win, WPP          WPP 0.0000
# 60                      Toti Casino             KDP          KDP 0.0000
# 61                     Vangie Abejo             KKK  Independent 0.0000
#
#                   Cash Contributions Received from Other Sources  \
# Candidate Number
# 1                                                         0.0000
# 2                                                         0.0000
# 3                                                         0.0000
# 4                                                         0.0000
# 5                                               126,350,000.0000
# ...                                                          ...
# 57                                                  400,000.0000
# 58                                                        0.0000
# 59                                                  102,000.0000
# 60                                                        0.0000
# 61                                                        0.0000
#
#                   In-Kind Contributions Received from Other Sources  \
# Candidate Number
# 1                                                            0.0000
# 2                                                            0.0000
# 3                                                            0.0000
# 4                                                            0.0000
# 5                                                      300,000.0000
# ...                                                             ...
# 57                                                     104,978.0000
# 58                                                           0.0000
# 59                                                     218,441.9100
# 60                                                           0.0000
# 61                                                           0.0000
#
#                   Cash Contributions Received from Political Party  \
# Candidate Number
# 1                                                           0.0000
# 2                                                           0.0000
# 3                                                           0.0000
# 4                                                           0.0000
# 5                                                           0.0000
# ...                                                            ...
# 57                                                          0.0000
# 58                                                          0.0000
# 59                                                          0.0000
# 60                                                          0.0000
# 61                                                          0.0000
#
#                   In-Kind Contributions Received from Political Party  \
# Candidate Number
# 1                                                            0.0000
# 2                                                            0.0000
# 3                                                            0.0000
# 4                                                            0.0000
# 5                                                            0.0000
# ...                                                             ...
# 57                                                           0.0000
# 58                                                 153,341,072.4100
# 59                                                           0.0000
# 60                                                           0.0000
# 61                                                           0.0000
#
#                   Total Contributions Received  Total Cash Contributions  \
# Candidate Number
# 1                                       0.0000                    0.0000
# 2                                       0.0000                    0.0000
# 3                                       0.0000                    0.0000
# 4                                       0.0000                    0.0000
# 5                             126,650,000.0000          126,350,000.0000
# ...                                        ...                       ...
# 57                                504,978.0000              400,000.0000
# 58                            153,341,072.4100                    0.0000
# 59                                320,441.9100              102,000.0000
# 60                                      0.0000                    0.0000
# 61                                      0.0000                    0.0000
#
#                   Total In-Kind Contributions
# Candidate Number
# 1                                      0.0000
# 2                                      0.0000
# 3                                      0.0000
# 4                                      0.0000
# 5                                300,000.0000
# ...                                       ...
# 57                               104,978.0000
# 58                           153,341,072.4100
# 59                               218,441.9100
# 60                                     0.0000
# 61                                     0.0000
#
# [62 rows x 11 columns]

# %% [markdown]
# # [NOT INCLUDED] Bar Chart - Contrib vs Expenditure

# %%
df_raw = pd.read_csv('data/2019-candidate-campaigns.csv', index_col=0)
df_win = df_raw[df_raw["Win"]==1]
cands = df_raw.iloc[:, :1]
win = df_raw.loc[:, "Win"]
contrib = df_raw.loc[:, "Total Contributions Received"]
exp = df_raw.loc[:, "Total Expenditures Incurred"]

df_draft = pd.concat([cands, win, contrib, exp], axis=1)
df_win = df_draft[df_draft["Win"]==1]
df_lose = df_draft[df_draft["Win"]==0]

# %%
df_win = df_win.sort_values("Total Expenditures Incurred", ascending = False)
df_lose = df_lose.sort_values("Total Expenditures Incurred", ascending = False)

df_win1 = df_win.drop("Win", axis=1)
df_lose1 = df_lose.drop("Win", axis=1)

win = pd.melt(df_win1, id_vars="Candidate")
lose = pd.melt(df_lose1, id_vars="Candidate")

# %% [markdown]
# #### [NOT INCLUDED] Winning Candidates plot

# %%
plt.figure(figsize=(15, 8))
sns.barplot(x="value", y="Candidate", hue="variable", data=win)

plt.title('Contributions vs. Expenditures of Candidates who Won', fontsize = 20)
plt.xlabel('Amount', fontsize=12)
plt.yticks(fontsize=15)

plt.show()

# %% [markdown]
# #### [NOT INCLUDED] Losing Candidates Plot

# %%
plt.figure(figsize=(15, 8))
sns.barplot(x="value", y="Candidate", hue="variable", data=lose)


plt.title('Contributions vs. Expenditures of Candidates who Lost', fontsize = 20)
plt.xlabel('Amount', fontsize=12)
plt.yticks(fontsize=13)

plt.show()

# %% [markdown]
# # BOX PLOT - Contributions Analysis

# %%
win = df.iloc[:, :4]
total_contrib = df.iloc[:, 8:]
df1 = pd.concat([win, total_contrib], axis=1)

melted_df1=pd.melt(df1.iloc[:, 3:], id_vars="Win")
melted_df1
# Out:
#        Win                      variable            value
# 0   0.0000  Total Contributions Received           0.0000
# 1   0.0000  Total Contributions Received           0.0000
# 2   0.0000  Total Contributions Received           0.0000
# 3   0.0000  Total Contributions Received           0.0000
# 4   0.0000  Total Contributions Received 126,650,000.0000
# ..     ...                           ...              ...
# 181 0.0000   Total In-Kind Contributions     104,978.0000
# 182 1.0000   Total In-Kind Contributions 153,341,072.4100
# 183 0.0000   Total In-Kind Contributions     218,441.9100
# 184 0.0000   Total In-Kind Contributions           0.0000
# 185 0.0000   Total In-Kind Contributions           0.0000
#
# [186 rows x 3 columns]

# %%
plt.figure(figsize=(12,8), dpi = 150)

sns.boxplot(y = melted_df1['variable'],
            x = melted_df1['value'],
            hue = melted_df1['Win'])

plt.title('Boxplot of Contributions Received - Winners vs. Losers', fontsize = 20)
plt.ylabel('Contribution Sources', fontsize=12)
plt.xlabel('Amount of Contributions received', fontsize=12)
plt.xticks(fontsize=15)

plt.show()
